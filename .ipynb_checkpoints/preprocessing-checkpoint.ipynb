# %% [markdown]
# # Preprocessing
#
# Log transformation where neccessary, scaling, and imputation using Bayesian ridge regression.

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler, FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
#from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import BayesianRidge

# %% [markdown]
# ## Prep

# %%
data = pd.read_csv("../data/full.csv")

# %% [markdown]
# Restrict to OECD destinations:

# %%
oecd = [
    "AUS", "AUT", "BEL", "CAN", "CHL", "CZE", "DNK", 
    "EST", "FIN", "FRA", "DEU", "GRC", "HUN", "ISL", 
    "IRL", "ISR", "ITA", "JPN", "KOR", "LUX", "MEX", 
    "NLD", "NZL", "NOR", "POL", "PRT", "SVK", "SVN", 
    "ESP", "SWE", "CHE", "TUR", "GBR", "USA"
]

data = data[data["destination_iso3"].isin(oecd)].reset_index(drop=True)
data.shape
# Out:
# (167400, 31)

# %% [markdown]
# ## Transformations

# %% [markdown]
# I would like to one-hot encode countries to pass that information along aswell, but it unfortunately pushes the computation time for model-based imputation far beyond reasonable bounds; so we are just rolling with the numeric features.

# %%
log_features = list(data.filter(regex="conflict_deaths|gdp(?!_g)|disaster_deaths|population").columns)
numeric_features = list(data.select_dtypes(include=["number"]).drop(list(data.filter(regex="^total")), axis=1).columns)

# %%
log_transformer = FunctionTransformer(
    func=lambda X: X.assign(**{col: np.log1p(X[col]) for col in log_features}),
    validate=False
)

numeric_pipeline = Pipeline(steps=[
    ('log', log_transformer),
    ('scaler', MinMaxScaler())
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_pipeline, numeric_features)
    ],
    remainder='passthrough'
)

pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('imputer', IterativeImputer(estimator=BayesianRidge(), random_state=42, verbose=2, max_iter=500))
    #('imputer', IterativeImputer(estimator=RandomForestRegressor(n_estimators=10, random_state=42), random_state=42, verbose=2))
])

# %%
processed = pipeline.fit_transform(data[numeric_features])
# Out:
# [IterativeImputer] Completing matrix with shape (167400, 26)
# [IterativeImputer] Ending imputation round 1/500, elapsed time 7.01
# [IterativeImputer] Change: 2.9688210778880895, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 2/500, elapsed time 13.28
# [IterativeImputer] Change: 1.8640915006901981, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 3/500, elapsed time 19.80
# [IterativeImputer] Change: 4.280985559274475, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 4/500, elapsed time 26.52
# [IterativeImputer] Change: 1.5666651583245632, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 5/500, elapsed time 33.01
# [IterativeImputer] Change: 1.1776346688626254, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 6/500, elapsed time 39.59
# [IterativeImputer] Change: 0.7512913320652665, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 7/500, elapsed time 46.66
# [IterativeImputer] Change: 0.49579500754164996, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 8/500, elapsed time 53.22
# [IterativeImputer] Change: 0.38375109539711083, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 9/500, elapsed time 59.69
# [IterativeImputer] Change: 0.3137949083600411, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 10/500, elapsed time 66.37
# [IterativeImputer] Change: 0.2564491303477312, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 11/500, elapsed time 73.27
# [IterativeImputer] Change: 0.336916310545444, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 12/500, elapsed time 79.35
# [IterativeImputer] Change: 0.4320496869179804, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 13/500, elapsed time 85.64
# [IterativeImputer] Change: 0.4995949286539825, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 14/500, elapsed time 92.00
# [IterativeImputer] Change: 0.48721028973364033, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round
scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 160/500, elapsed time 1014.49
# [IterativeImputer] Change: 0.002130548706917701, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 161/500, elapsed time 1020.89
# [IterativeImputer] Change: 0.0020673406177891818, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 162/500, elapsed time 1027.15
# [IterativeImputer] Change: 0.0020048107705078477, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 163/500, elapsed time 1033.46
# [IterativeImputer] Change: 0.0019429813741312918, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 164/500, elapsed time 1039.75
# [IterativeImputer] Change: 0.0018818733950254352, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 165/500, elapsed time 1046.10
# [IterativeImputer] Change: 0.0018215065796597374, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 166/500, elapsed time 1052.37
# [IterativeImputer] Change: 0.001761899478305906, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 167/500, elapsed time 1058.56
# [IterativeImputer] Change: 0.0017030694688828785, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 168/500, elapsed time 1064.39
# [IterativeImputer] Change: 0.001645032781046607, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 169/500, elapsed time 1070.77
# [IterativeImputer] Change: 0.0015878045195490964, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 170/500, elapsed time 1076.95
# [IterativeImputer] Change: 0.0015483768441632018, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 171/500, elapsed time 1083.15
# [IterativeImputer] Change: 0.0015120948303327664, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 172/500, elapsed time 1089.39
# [IterativeImputer] Change: 0.0014759574458077518, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 173/500, elapsed time 1095.74
# [IterativeImputer] Change: 0.0014399842465708246, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 174/500, elapsed time 1101.92
# [IterativeImputer] Change: 0.0014041940564128996, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 175/500, elapsed time 1108.01
# [IterativeImputer] Change: 0.001368604976577592, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 176/500, elapsed time 1114.22
# [IterativeImputer] Change: 0.0013332343959714388, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 177/500, elapsed time 1120.53
# [IterativeImputer] Change: 0.0013004226034861177, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 178/500, elapsed time 1126.61
# [IterativeImputer] Change: 0.0012744239120631717, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 179/500, elapsed time 1132.86
# [IterativeImputer] Change: 0.0012484091133340702, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 180/500, elapsed time 1139.09
# [IterativeImputer] Change: 0.0012223960146507395, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 181/500, elapsed time 1145.40
# [IterativeImputer] Change: 0.0011964018491013584, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 182/500, elapsed time 1151.55
# [IterativeImputer] Change: 0.0011704432826004085, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 183/500, elapsed time 1157.68
# [IterativeImputer] Change: 0.0011445364211666864, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 184/500, elapsed time 1163.90
# [IterativeImputer] Change: 0.0011186968176720158, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 185/500, elapsed time 1170.18
# [IterativeImputer] Change: 0.001092939479538202, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 186/500, elapsed time 1176.21
# [IterativeImputer] Change: 0.001067278876241251, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 187/500, elapsed time 1182.48
# [IterativeImputer] Change: 0.001041728947502818, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 188/500, elapsed time 1188.72
# [IterativeImputer] Change: 0.001025335078627232, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 189/500, elapsed time 1195.08
# [IterativeImputer] Change: 0.0010102287404288868, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Ending imputation round 190/500, elapsed time 1201.25
# [IterativeImputer] Change: 0.000997252431885809, scaled tolerance: 0.0010000000000000005
# [IterativeImputer] Early stopping criterion reached.

# %%
final = pd.concat([
    data[["origin_iso3", "destination_iso3", "year", "total_linear"]],
    pd.DataFrame(processed, columns=numeric_features).drop("year", axis=1)
], axis=1)

# %%
final.to_csv("../data/processed_data.csv")
